# %% [markdown]
# # Philips Digital Diagnost - Image Data Table Parser

# %% [markdown]
# This notebook takes the output of the QA Tool > Image Data Table export from a Philips Digital Diagnost and produces a .csv file that can be appended to the Reject Analysis and Dose Metric Dashboard database.

# %% [markdown]
# Let's start by importing the required libraries needed to make the parser work.

# %%
import pandas as pd
import os

from ipywidgets import *
from tkinter import Tk, filedialog
from IPython.display import clear_output, display

# %% [markdown]
# The template for the Reject Analysis and Dose Metric Dashboard is as follows:

# %%
cols_list_final = ['Asset Number','DeviceID','Manufacturer','Model','Image Date','Image Time','Body Part','View','Exposure Index','KAP (uGy.m2)','kVp','Exposure (mAs)','Exposure time (ms)','Image Status','Reject Reason']

df_template = pd.DataFrame(columns=[*cols_list_final])
df_template
# Out:
# Empty DataFrame
# Columns: [Asset Number, DeviceID, Manufacturer, Model, Image Date, Image Time, Body Part, View, Exposure Index, KAP (uGy.m2), kVp, Exposure (mAs), Exposure time (ms), Image Status, Reject Reason]
# Index: []

# %% [markdown]
# To clean up an export, you'll need to select the exported files from the Philips QA Tool using the "File Select" button below.
# <br>
# You will also be asked for your asset number so that we can group systems in the Dashboard by facility.

# %%
# Select input Image Data Table file as exported from Philips QA tool

def select_files(b):
    clear_output()
    root = Tk()
    root.withdraw() # Hide the main window.
    root.call('wm', 'attributes', '.', '-topmost', True) # Raise the root to the top of all windows.
    b.files = filedialog.askopenfilename(multiple=True) # List of selected files will be set button's file attribute.
    print(b.files) # Print the list of files selected.

fileselect = Button(description="File select")
fileselect.on_click(select_files)

display(fileselect)
# Out:
# ('C:/Users/bernardm/GitHub/JupyterNotebooks/rejectAnalysis/inputdata/Reject_Analysis_Table_QHSCHDXC07_20201202_1_ACC_Xray_Room2.csv', 'C:/Users/bernardm/GitHub/JupyterNotebooks/rejectAnalysis/inputdata/Reject_Analysis_Table_QHSCHDXC08_20201202_1_ACC_Xray_Room1.csv')

# %%
# Confirm how many files are selected

files = fileselect.files
print("The first file name is: ", files[0])
# Out:
# The first file name is:  C:/Users/bernardm/GitHub/JupyterNotebooks/rejectAnalysis/inputdata/Reject_Analysis_Table_QHSCHDXC07_20201202_1_ACC_Xray_Room2.csv

# %%
# Use the filepath of the .csv file
f = files[0]

print("What is the asset number of the system?")
AssetNumber = input()
# Out:
# What is the asset number of the system?
# 12345667

# %% [markdown]
# The default filename created by the Philips QA tool includes the DeviceID on the first cell in the first column.
# <br>
# Let's extract out the DeviceID of the Philips Digital Diagnost from the Image Data Table you collected.

# %%
# Get the DeviceID from the filename of the .csv file

fn = os.path.basename(f)
DeviceID = fn[22:32]
print("The DeviceID is",DeviceID)
# Out:
# The DeviceID is QHSCHDXC07

# %% [markdown]
# Let's do some clean-up on the .csv file:
# - Skip the first four rows of the Image Data Table since they're blank
# - Define the separator. By default, this will be ";". However, this can be set to something different during export (| or , or -). Change the code below if your separator is something other than ";".

# %%
df = pd.read_csv(f, sep =';', skiprows=4, error_bad_lines = False )
df
# Out:
# b'Skipping line 7136: expected 19 fields, saw 20\n'
#        Image date   Image time Study description Protocol step name step  \
# 0      02/07/2020  10:39:58 AM           Wrist L                 Lateral
# 1      02/07/2020  10:39:25 AM           Wrist L                      PA
# 2      02/07/2020  11:19:54 AM           Wrist L                 Lateral
# 3      02/07/2020  11:19:18 AM           Wrist L                 Lateral
# 4      02/07/2020  11:18:54 AM           Wrist L                      PA
# ...           ...          ...               ...                     ...
# 10796  02/12/2020   8:59:19 AM           Elbow L                      AP
# 10797  02/12/2020   8:57:21 AM           Elbow L                 Lateral
# 10798  02/12/2020   9:03:37 AM           Thumb R                      AP
# 10799  02/12/2020   9:05:06 AM           Thumb R                     Lat
# 10800  02/12/2020   9:04:01 AM           Thumb R                 Oblique
#
#         kVp  Exposure [mAs]  Exposure time [ms] Relative x-ray exposure  \
# 0      57.0             3.0                10.0                     473
# 1      55.0             2.0                10.0                     243
# 2      57.0             3.0                10.0                     615
# 3      57.0             3.0                10.0                     565
# 4      55.0             2.0                10.0                     416
# ...     ...             ...                 ...                     ...
# 10796  60.0             3.0                10.0                     393
# 10797  60.0             3.0                10.0                     760
# 10798  42.0             4.0                18.0                     376
# 10799  42.0             4.0                18.0                     410
# 10800  42.0             4.0                18.0                     434
#
#       Image dose area product [µGy m²]                    Image comments  \
# 0                                 3.23                               NaN
# 1                                  1.5                               NaN
# 2                                 3.05  Image rejected. Not True Lateral
# 3                                 3.05                               NaN
# 4                                 1.87                               NaN
# ...                                ...                               ...
# 10796                             2.83                               NaN
# 10797                              4.1                               NaN
# 10798                             0.53                               NaN
# 10799                             0.53                               NaN
# 10800                             0.53                               NaN
#
#           Reject reason     Status Modality Operators name Image link  \
# 0                   NaN  confirmed       DX           user    [Image]
# 1                   NaN  confirmed       DX           user    [Image]
# 2      Not True Lateral   rejected       DX           user    [Image]
# 3                   NaN  confirmed       DX           user    [Image]
# 4                   NaN  confirmed       DX           user    [Image]
# ...                 ...        ...      ...            ...        ...
# 10796               NaN  confirmed       DX           user    [Image]
# 10797               NaN  confirmed       DX           user    [Image]
# 10798               NaN  confirmed       DX           user    [Image]
# 10799               NaN  confirmed       DX           user    [Image]
# 10800               NaN  confirmed       DX           user    [Image]
#
#       Patient sex Patient's age Pregnancy status  Unnamed: 18
# 0               F          073Y          Unknown          NaN
# 1               F          073Y          Unknown          NaN
# 2               F          064Y          Unknown          NaN
# 3               F          064Y          Unknown          NaN
# 4               F          064Y          Unknown          NaN
# ...           ...           ...              ...          ...
# 10796           F          050Y          Unknown          NaN
# 10797           F          050Y          Unknown          NaN
# 10798           M          008Y          Unknown          NaN
# 10799           M          008Y          Unknown          NaN
# 10800           M          008Y          Unknown          NaN
#
# [10801 rows x 19 columns]

# %% [markdown]
# If the .csv file has been read in correctly above, you should see a table with all the values from the log.
# <br>
# Let's add a few identifiers for filtering purposes:
# - Asset Number
# - Device ID (e.g. unique system ID, serial number or even room number)
# - Manufacturer
# - Model

# %%
cols_list = ['Asset Number','DeviceID','Manufacturer','Model']
df = df.reindex(columns=[*cols_list,*df.columns.tolist()])

df['Asset Number'] = AssetNumber
df['DeviceID'] = DeviceID
df['Manufacturer'] = "Philips"
df['Model'] = "Digital Diagnost"
df
# Out:
#       Asset Number    DeviceID Manufacturer             Model  Image date  \
# 0         12345667  QHSCHDXC07      Philips  Digital Diagnost  02/07/2020
# 1         12345667  QHSCHDXC07      Philips  Digital Diagnost  02/07/2020
# 2         12345667  QHSCHDXC07      Philips  Digital Diagnost  02/07/2020
# 3         12345667  QHSCHDXC07      Philips  Digital Diagnost  02/07/2020
# 4         12345667  QHSCHDXC07      Philips  Digital Diagnost  02/07/2020
# ...            ...         ...          ...               ...         ...
# 10796     12345667  QHSCHDXC07      Philips  Digital Diagnost  02/12/2020
# 10797     12345667  QHSCHDXC07      Philips  Digital Diagnost  02/12/2020
# 10798     12345667  QHSCHDXC07      Philips  Digital Diagnost  02/12/2020
# 10799     12345667  QHSCHDXC07      Philips  Digital Diagnost  02/12/2020
# 10800     12345667  QHSCHDXC07      Philips  Digital Diagnost  02/12/2020
#
#         Image time Study description Protocol step name step   kVp  \
# 0      10:39:58 AM           Wrist L                 Lateral  57.0
# 1      10:39:25 AM           Wrist L                      PA  55.0
# 2      11:19:54 AM           Wrist L                 Lateral  57.0
# 3      11:19:18 AM           Wrist L                 Lateral  57.0
# 4      11:18:54 AM           Wrist L                      PA  55.0
# ...            ...               ...                     ...   ...
# 10796   8:59:19 AM           Elbow L                      AP  60.0
# 10797   8:57:21 AM           Elbow L                 Lateral  60.0
# 10798   9:03:37 AM           Thumb R                      AP  42.0
# 10799   9:05:06 AM           Thumb R                     Lat  42.0
# 10800   9:04:01 AM           Thumb R                 Oblique  42.0
#
#        Exposure [mAs]  ...                    Image comments  \
# 0                 3.0  ...                               NaN
# 1                 2.0  ...                               NaN
# 2                 3.0  ...  Image rejected. Not True Lateral
# 3                 3.0  ...                               NaN
# 4                 2.0  ...                               NaN
# ...               ...  ...                               ...
# 10796             3.0  ...                               NaN
# 10797             3.0  ...                               NaN
# 10798             4.0  ...                               NaN
# 10799             4.0  ...                               NaN
# 10800             4.0  ...                               NaN
#
#           Reject reason     Status Modality Operators name Image link  \
# 0                   NaN  confirmed       DX           user    [Image]
# 1                   NaN  confirmed       DX           user    [Image]
# 2      Not True Lateral   rejected       DX           user    [Image]
# 3                   NaN  confirmed       DX           user    [Image]
# 4                   NaN  confirmed       DX           user    [Image]
# ...                 ...        ...      ...            ...        ...
# 10796               NaN  confirmed       DX           user    [Image]
# 10797               NaN  confirmed       DX           user    [Image]
# 10798               NaN  confirmed       DX           user    [Image]
# 10799               NaN  confirmed       DX           user    [Image]
# 10800               NaN  confirmed       DX           user    [Image]
#
#       Patient sex Patient's age Pregnancy status Unnamed: 18
# 0               F          073Y          Unknown         NaN
# 1               F          073Y          Unknown         NaN
# 2               F          064Y          Unknown         NaN
# 3               F          064Y          Unknown         NaN
# 4               F          064Y          Unknown         NaN
# ...           ...           ...              ...         ...
# 10796           F          050Y          Unknown         NaN
# 10797           F          050Y          Unknown         NaN
# 10798           M          008Y          Unknown         NaN
# 10799           M          008Y          Unknown         NaN
# 10800           M          008Y          Unknown         NaN
#
# [10801 rows x 23 columns]

# %% [markdown]
# Let's match the .csv columns into the template:
# - rename the columns of the original .csv file to match the template
# - remove any columns we don't need
# - rearrange the columns to match the template

# %%
df = df.rename(columns={"Study description": "Body Part",
                       "Protocol step name step": "View",
                        "Relative x-ray exposure": "Exposure Index",
                        "Exposure [mAs]": "Exposure (mAs)",
                        "Exposure time [ms]": "Exposure time (ms)",
                        "Status": "Image Status",
                        "Reject reason": "Reject Reason",
                        "Image dose area product [µGy m²]": "KAP (uGy.m2)",
                        "Image date": "Image Date",
                        "Image time": 'Image Time'
                       })

df_out = df[[*cols_list_final]]
df_out
# Out:
#       Asset Number    DeviceID Manufacturer             Model  Image Date  \
# 0         12345667  QHSCHDXC07      Philips  Digital Diagnost  02/07/2020
# 1         12345667  QHSCHDXC07      Philips  Digital Diagnost  02/07/2020
# 2         12345667  QHSCHDXC07      Philips  Digital Diagnost  02/07/2020
# 3         12345667  QHSCHDXC07      Philips  Digital Diagnost  02/07/2020
# 4         12345667  QHSCHDXC07      Philips  Digital Diagnost  02/07/2020
# ...            ...         ...          ...               ...         ...
# 10796     12345667  QHSCHDXC07      Philips  Digital Diagnost  02/12/2020
# 10797     12345667  QHSCHDXC07      Philips  Digital Diagnost  02/12/2020
# 10798     12345667  QHSCHDXC07      Philips  Digital Diagnost  02/12/2020
# 10799     12345667  QHSCHDXC07      Philips  Digital Diagnost  02/12/2020
# 10800     12345667  QHSCHDXC07      Philips  Digital Diagnost  02/12/2020
#
#         Image Time Body Part     View Exposure Index KAP (uGy.m2)   kVp  \
# 0      10:39:58 AM   Wrist L  Lateral            473         3.23  57.0
# 1      10:39:25 AM   Wrist L       PA            243          1.5  55.0
# 2      11:19:54 AM   Wrist L  Lateral            615         3.05  57.0
# 3      11:19:18 AM   Wrist L  Lateral            565         3.05  57.0
# 4      11:18:54 AM   Wrist L       PA            416         1.87  55.0
# ...            ...       ...      ...            ...          ...   ...
# 10796   8:59:19 AM   Elbow L       AP            393         2.83  60.0
# 10797   8:57:21 AM   Elbow L  Lateral            760          4.1  60.0
# 10798   9:03:37 AM   Thumb R       AP            376         0.53  42.0
# 10799   9:05:06 AM   Thumb R      Lat            410         0.53  42.0
# 10800   9:04:01 AM   Thumb R  Oblique            434         0.53  42.0
#
#        Exposure (mAs)  Exposure time (ms) Image Status     Reject Reason
# 0                 3.0                10.0    confirmed               NaN
# 1                 2.0                10.0    confirmed               NaN
# 2                 3.0                10.0     rejected  Not True Lateral
# 3                 3.0                10.0    confirmed               NaN
# 4                 2.0                10.0    confirmed               NaN
# ...               ...                 ...          ...               ...
# 10796             3.0                10.0    confirmed               NaN
# 10797             3.0                10.0    confirmed               NaN
# 10798             4.0                18.0    confirmed               NaN
# 10799             4.0                18.0    confirmed               NaN
# 10800             4.0                18.0    confirmed               NaN
#
# [10801 rows x 15 columns]

# %% [markdown]
# Check the output table above and confirm that the information matches the column names.
# If everything is OK, let's export the cleaned up .csv file into an output file.
#
# By default, this creates a new .csv file with the name "df_out". Change the code below to rename it to something unique with a timestamp if preferred.

# %%
# Add timestamp to filename
from datetime import datetime
date = datetime.now().strftime("%Y_%m_%d_%I_%S%p")

df_out.to_csv((r'C:\Users\BernardM\GitHub\JupyterNotebooks\rejectAnalysis\outputdata\\'
               +str(AssetNumber)
               +'_'
               +str(date)
               +'.csv')
               ,index = False, header = True)

print("The output file has been successfully saved.")
# Out:
# The output file has been successfully saved.

# %% [markdown]
# This output file can now be appended to the Reject Analysis and Dose Metric Dashboard database.
