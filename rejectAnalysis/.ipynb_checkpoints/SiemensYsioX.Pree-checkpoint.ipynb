# %% [markdown]
# # Siemens Ysio X.Pree - Reject Log Parser

# %% [markdown]
# This notebook takes the output of the Reject Log export from a Siemens X-ray system and produces a .csv file that can be appended to the Reject Analysis and Dose Metric Dashboard database.

# %% [markdown]
# Let's start by importing the required libraries needed to make the parser work.

# %%
import pandas as pd
import os

from ipywidgets import *
from tkinter import Tk, filedialog
from IPython.display import clear_output, display

# %% [markdown]
# The template for the database used in the Reject Analysis and Dose Metric Dashboard is as follows:

# %%
cols_list_final = ['Asset Number','Manufacturer','Model','Image Date','Image Time','Body Part','View','Exposure Index','KAP (uGy.m2)','kVp','Exposure (mAs)','Exposure time (ms)','Image Status','Reject Reason']

df_template = pd.DataFrame(columns=[*cols_list_final])
df_template
# Out:
# Empty DataFrame
# Columns: [Asset Number, Manufacturer, Model, Image Date, Image Time, Body Part, View, Exposure Index, KAP (uGy.m2), kVp, Exposure (mAs), Exposure time (ms), Image Status, Reject Reason]
# Index: []

# %% [markdown]
# ## Selecting file from file browser

# %% [markdown]
# To clean up an export, you'll need to select the exported files from the Philips QA Tool using the "File Select" button below.
# <br>
# You will also be asked for your asset number so that we can group systems in the Dashboard by facility.

# %%
# Select input log from file location

def select_files(b):
    clear_output()
    root = Tk()
    root.withdraw() # Hide the main window.
    root.call('wm', 'attributes', '.', '-topmost', True) # Raise the root to the top of all windows.
    b.files = filedialog.askopenfilename() # List of selected files will be set button's file attribute.
    print(b.files) # Print the list of files selected.

fileselect = Button(description="File select")
fileselect.on_click(select_files)

display(fileselect)
# Out:
# C:/Users/bernardm/GitHub/JupyterNotebooks/rejectAnalysis/inputdata/Ysio X.Pree example reject log.xlsx

# %% [markdown]
# ## Adding Asset Number

# %% [markdown]
# In the next section, the file that you've selected will be printed out and you'll be asked to input the Asset Number of the system. Type the Asset Number in the box provided and then press "ENTER".

# %%
files = fileselect.files
print("The file you've selected is: ", files)
print()
print("What is the asset number of the system?")

AssetNumber = input()
# Out:
# The file you've selected is:  C:/Users/bernardm/GitHub/JupyterNotebooks/rejectAnalysis/inputdata/Ysio X.Pree example reject log.xlsx
#
# What is the asset number of the system?
# 123

# %% [markdown]
# ## Clean up dataframe

# %% [markdown]
# Let's do some clean-up on the .csv file:
# - Define the separator. By default, this will be ";". However, this can be set to something different during export (| or , or -). Change the code below if your separator is something other than ";".

# %%
df = pd.read_excel(files,skiprows=6)
df
# Out:
#    Acquisition Date/Time      Clinical Protocol Name Body Part  \
# 0    2022-06-24 10:52:00                     L ANKLE     ANKLE
# 1    2022-06-24 11:11:00                       CHEST     CHEST
# 2    2022-06-24 11:53:00               PELVIS, R HIP       HIP
# 3    2022-06-24 13:25:00                     ABDOMEN   ABDOMEN
# 4    2022-06-24 16:14:00                       CHEST     CHEST
# 5    2022-06-24 16:22:00                       CHEST     CHEST
# 6    2022-06-24 16:26:00                       CHEST     CHEST
# 7    2022-06-25 22:30:00            CHEST, COVID ?/+     CHEST
# 8    2022-06-26 13:47:00                       CHEST     CHEST
# 9    2022-06-26 14:01:00  L SPINE, LS SPINE, T SPINE    LSPINE
# 10   2022-06-27 15:37:00      L CLAVICLE, L SHOULDER  SHOULDER
# 11   2022-06-27 16:10:00                  R SHOULDER  SHOULDER
# 12   2022-06-27 16:36:00                     ABDOMEN   ABDOMEN
# 13   2022-06-28 09:32:00                       CHEST     CHEST
# 14   2022-06-28 09:49:00         ABDOMEN, L SHOULDER  SHOULDER
# 15   2022-06-28 10:14:00          ABDOMEN, T/L SPINE    LSPINE
# 16   2022-06-28 10:30:00            Spine - Thoracic    TSPINE
# 17   2022-06-28 10:32:00          ABDOMEN, T/L SPINE    LSPINE
#
#               Clinical Protocol Step Name  Study Instance UID  \
# 0                                 X Ankle                 NaN
# 1                      W Chest - PA Erect                 NaN
# 2   X Hip - Horiz. Beam Lateral Tube Left                 NaN
# 3                               T Abdomen                 NaN
# 4                      W Chest - PA Erect                 NaN
# 5                      W Chest - PA Erect                 NaN
# 6                      W Chest - PA Erect                 NaN
# 7                            X Chest - AP                 NaN
# 8                      W Chest - PA Erect                 NaN
# 9         W Lumbar Spine - Lateral Supine                 NaN
# 10                      Shoulder - Y-View                 NaN
# 11                      Shoulder - Y-View                 NaN
# 12                              T Abdomen                 NaN
# 13                      W Chest - Lateral                 NaN
# 14                      Shoulder - Y-View                 NaN
# 15      X Lumbar Spine - AP Free Detector                 NaN
# 16        Thoracic Spine - Lateral Supine                 NaN
# 17        W Lumbar Spine - Lateral Supine                 NaN
#
#     SOP Instance UID Operator Name Rejection Date/Time   Reason for Rejection  \
# 0                NaN           --- 2022-06-24 10:53:00  03. Positioning Error
# 1                NaN           --- 2022-06-24 11:12:00     06. Anatomy Cutoff
# 2                NaN           --- 2022-06-24 12:09:00  03. Positioning Error
# 3                NaN           --- 2022-06-24 13:27:00     06. Anatomy Cutoff
# 4                NaN           --- 2022-06-24 16:22:00  03. Positioning Error
# 5                NaN           --- 2022-06-24 16:23:00  03. Positioning Error
# 6                NaN           --- 2022-06-24 16:27:00  03. Positioning Error
# 7                NaN           --- 2022-06-25 22:32:00     06. Anatomy Cutoff
# 8                NaN           --- 2022-06-26 13:47:00     06. Anatomy Cutoff
# 9                NaN           --- 2022-06-26 14:01:00     06. Anatomy Cutoff
# 10               NaN           --- 2022-06-27 15:38:00  03. Positioning Error
# 11               NaN           --- 2022-06-27 16:11:00  03. Positioning Error
# 12               NaN           --- 2022-06-27 16:39:00  03. Positioning Error
# 13               NaN           --- 2022-06-28 09:33:00  03. Positioning Error
# 14               NaN           --- 2022-06-28 09:53:00  03. Positioning Error
# 15               NaN           --- 2022-06-28 10:35:00  03. Positioning Error
# 16               NaN           --- 2022-06-28 10:34:00     06. Anatomy Cutoff
# 17               NaN           --- 2022-06-28 10:34:00     06. Anatomy Cutoff
#
#    Rejected by  Target EXI  Clinical EXI Image Type     kV    mAs
# 0          ---         250            82         2D   56.9    2.1
# 1          ---         320           525         2D  124.9    4.4
# 2          ---         250           648         2D   65.9    7.2
# 3          ---         360           458         2D   80.9   60.8
# 4          ---         250           447         2D  124.9    1.5
# 5          ---         250           404         2D  124.9    1.5
# 6          ---         250           407         2D  124.9    1.4
# 7          ---         250           682         2D  104.9    3.3
# 8          ---         250           476         2D  124.9    1.1
# 9          ---         250           177         2D   89.8   40.1
# 10         ---         250           216         2D   59.8    5.0
# 11         ---         250           369         2D   72.9    8.1
# 12         ---         450           678         2D   80.9   38.1
# 13         ---         250           529         2D  124.9    3.8
# 14         ---         250           452         2D   72.9    9.5
# 15         ---         250           612         2D   74.8   25.1
# 16         ---         250           136         2D   80.9   13.5
# 17         ---         250           426         2D   89.7  192.6

# %% [markdown]
# ## Adding unique identifiers

# %% [markdown]
# If the .csv file has been read in correctly above, you should see a table with all the values from the log.
# <br>
# Let's add a few identifiers for filtering purposes:
# - Asset Number
# - Manufacturer
# - Model
#
# The Siemens reject log does not have the following columns and has been set to NONE:
# - Exposure time (ms)
# - Image Time
# - KAP (uGy.m2)

# %%
cols_list = ['Asset Number','Manufacturer','Model']
df = df.reindex(columns=[*cols_list,*df.columns.tolist()])

df['Asset Number'] = AssetNumber
df['Manufacturer'] = "Siemens"
df['Model'] = "Ysio X.Pree"
df['Image Status'] = df['Reason for Rejection'].apply(lambda x: 'Rejected' if pd.notnull(x) else 'Approved')

df['Exposure time (ms)'] = None
df['Image Time'] = None
df['KAP (uGy.m2)'] = None

df
# Out:
#    Asset Number Manufacturer        Model Acquisition Date/Time  \
# 0           123      Siemens  Ysio X.Pree   2022-06-24 10:52:00
# 1           123      Siemens  Ysio X.Pree   2022-06-24 11:11:00
# 2           123      Siemens  Ysio X.Pree   2022-06-24 11:53:00
# 3           123      Siemens  Ysio X.Pree   2022-06-24 13:25:00
# 4           123      Siemens  Ysio X.Pree   2022-06-24 16:14:00
# 5           123      Siemens  Ysio X.Pree   2022-06-24 16:22:00
# 6           123      Siemens  Ysio X.Pree   2022-06-24 16:26:00
# 7           123      Siemens  Ysio X.Pree   2022-06-25 22:30:00
# 8           123      Siemens  Ysio X.Pree   2022-06-26 13:47:00
# 9           123      Siemens  Ysio X.Pree   2022-06-26 14:01:00
# 10          123      Siemens  Ysio X.Pree   2022-06-27 15:37:00
# 11          123      Siemens  Ysio X.Pree   2022-06-27 16:10:00
# 12          123      Siemens  Ysio X.Pree   2022-06-27 16:36:00
# 13          123      Siemens  Ysio X.Pree   2022-06-28 09:32:00
# 14          123      Siemens  Ysio X.Pree   2022-06-28 09:49:00
# 15          123      Siemens  Ysio X.Pree   2022-06-28 10:14:00
# 16          123      Siemens  Ysio X.Pree   2022-06-28 10:30:00
# 17          123      Siemens  Ysio X.Pree   2022-06-28 10:32:00
#
#         Clinical Protocol Name Body Part  \
# 0                      L ANKLE     ANKLE
# 1                        CHEST     CHEST
# 2                PELVIS, R HIP       HIP
# 3                      ABDOMEN   ABDOMEN
# 4                        CHEST     CHEST
# 5                        CHEST     CHEST
# 6                        CHEST     CHEST
# 7             CHEST, COVID ?/+     CHEST
# 8                        CHEST     CHEST
# 9   L SPINE, LS SPINE, T SPINE    LSPINE
# 10      L CLAVICLE, L SHOULDER  SHOULDER
# 11                  R SHOULDER  SHOULDER
# 12                     ABDOMEN   ABDOMEN
# 13                       CHEST     CHEST
# 14         ABDOMEN, L SHOULDER  SHOULDER
# 15          ABDOMEN, T/L SPINE    LSPINE
# 16            Spine - Thoracic    TSPINE
# 17          ABDOMEN, T/L SPINE    LSPINE
#
#               Clinical Protocol Step Name  Study Instance UID  \
# 0                                 X Ankle                 NaN
# 1                      W Chest - PA Erect                 NaN
# 2   X Hip - Horiz. Beam Lateral Tube Left                 NaN
# 3                               T Abdomen                 NaN
# 4                      W Chest - PA Erect                 NaN
# 5                      W Chest - PA Erect                 NaN
# 6                      W Chest - PA Erect                 NaN
# 7                            X Chest - AP                 NaN
# 8                      W Chest - PA Erect                 NaN
# 9         W Lumbar Spine - Lateral Supine                 NaN
# 10                      Shoulder - Y-View                 NaN
# 11                      Shoulder - Y-View                 NaN
# 12                              T Abdomen                 NaN
# 13                      W Chest - Lateral                 NaN
# 14                      Shoulder - Y-View                 NaN
# 15      X Lumbar Spine - AP Free Detector                 NaN
# 16        Thoracic Spine - Lateral Supine                 NaN
# 17        W Lumbar Spine - Lateral Supine                 NaN
#
#     SOP Instance UID Operator Name  ... Rejected by Target EXI Clinical EXI  \
# 0                NaN           ---  ...         ---        250           82
# 1                NaN           ---  ...         ---        320          525
# 2                NaN           ---  ...         ---        250          648
# 3                NaN           ---  ...         ---        360          458
# 4                NaN           ---  ...         ---        250          447
# 5                NaN           ---  ...         ---        250          404
# 6                NaN           ---  ...         ---        250          407
# 7                NaN           ---  ...         ---        250          682
# 8                NaN           ---  ...         ---        250          476
# 9                NaN           ---  ...         ---        250          177
# 10               NaN           ---  ...         ---        250          216
# 11               NaN           ---  ...         ---        250          369
# 12               NaN           ---  ...         ---        450          678
# 13               NaN           ---  ...         ---        250          529
# 14               NaN           ---  ...         ---        250          452
# 15               NaN           ---  ...         ---        250          612
# 16               NaN           ---  ...         ---        250          136
# 17               NaN           ---  ...         ---        250          426
#
#     Image Type     kV    mAs  Image Status  Exposure time (ms) Image Time  \
# 0           2D   56.9    2.1      Rejected                None       None
# 1           2D  124.9    4.4      Rejected                None       None
# 2           2D   65.9    7.2      Rejected                None       None
# 3           2D   80.9   60.8      Rejected                None       None
# 4           2D  124.9    1.5      Rejected                None       None
# 5           2D  124.9    1.5      Rejected                None       None
# 6           2D  124.9    1.4      Rejected                None       None
# 7           2D  104.9    3.3      Rejected                None       None
# 8           2D  124.9    1.1      Rejected                None       None
# 9           2D   89.8   40.1      Rejected                None       None
# 10          2D   59.8    5.0      Rejected                None       None
# 11          2D   72.9    8.1      Rejected                None       None
# 12          2D   80.9   38.1      Rejected                None       None
# 13          2D  124.9    3.8      Rejected                None       None
# 14          2D   72.9    9.5      Rejected                None       None
# 15          2D   74.8   25.1      Rejected                None       None
# 16          2D   80.9   13.5      Rejected                None       None
# 17          2D   89.7  192.6      Rejected                None       None
#
#    KAP (uGy.m2)
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None
# 8          None
# 9          None
# 10         None
# 11         None
# 12         None
# 13         None
# 14         None
# 15         None
# 16         None
# 17         None
#
# [18 rows x 22 columns]

# %% [markdown]
# ## Putting data into the template dataframe

# %% [markdown]
# Let's match the .csv columns into the template:
# - rename the columns of the original .csv file to match the template
# - remove any columns we don't need
# - rearrange the columns to match the template

# %%
df = df.rename(columns={"Body Part": "Body Part",
                       "Clinical Protocol Step Name": "View",
                        "Clinical EXI": "Exposure Index",
                        "kV": "kVp",
                        "mAs": "Exposure (mAs)",
                        "Reason for Rejection": "Reject Reason",
                        "Rejection Date/Time": "Image Date",
                       })

df_out = df[[*cols_list_final]]
df_out
# Out:
#    Asset Number Manufacturer        Model          Image Date Image Time  \
# 0           123      Siemens  Ysio X.Pree 2022-06-24 10:53:00       None
# 1           123      Siemens  Ysio X.Pree 2022-06-24 11:12:00       None
# 2           123      Siemens  Ysio X.Pree 2022-06-24 12:09:00       None
# 3           123      Siemens  Ysio X.Pree 2022-06-24 13:27:00       None
# 4           123      Siemens  Ysio X.Pree 2022-06-24 16:22:00       None
# 5           123      Siemens  Ysio X.Pree 2022-06-24 16:23:00       None
# 6           123      Siemens  Ysio X.Pree 2022-06-24 16:27:00       None
# 7           123      Siemens  Ysio X.Pree 2022-06-25 22:32:00       None
# 8           123      Siemens  Ysio X.Pree 2022-06-26 13:47:00       None
# 9           123      Siemens  Ysio X.Pree 2022-06-26 14:01:00       None
# 10          123      Siemens  Ysio X.Pree 2022-06-27 15:38:00       None
# 11          123      Siemens  Ysio X.Pree 2022-06-27 16:11:00       None
# 12          123      Siemens  Ysio X.Pree 2022-06-27 16:39:00       None
# 13          123      Siemens  Ysio X.Pree 2022-06-28 09:33:00       None
# 14          123      Siemens  Ysio X.Pree 2022-06-28 09:53:00       None
# 15          123      Siemens  Ysio X.Pree 2022-06-28 10:35:00       None
# 16          123      Siemens  Ysio X.Pree 2022-06-28 10:34:00       None
# 17          123      Siemens  Ysio X.Pree 2022-06-28 10:34:00       None
#
#    Body Part                                   View  Exposure Index  \
# 0      ANKLE                                X Ankle              82
# 1      CHEST                     W Chest - PA Erect             525
# 2        HIP  X Hip - Horiz. Beam Lateral Tube Left             648
# 3    ABDOMEN                              T Abdomen             458
# 4      CHEST                     W Chest - PA Erect             447
# 5      CHEST                     W Chest - PA Erect             404
# 6      CHEST                     W Chest - PA Erect             407
# 7      CHEST                           X Chest - AP             682
# 8      CHEST                     W Chest - PA Erect             476
# 9     LSPINE        W Lumbar Spine - Lateral Supine             177
# 10  SHOULDER                      Shoulder - Y-View             216
# 11  SHOULDER                      Shoulder - Y-View             369
# 12   ABDOMEN                              T Abdomen             678
# 13     CHEST                      W Chest - Lateral             529
# 14  SHOULDER                      Shoulder - Y-View             452
# 15    LSPINE      X Lumbar Spine - AP Free Detector             612
# 16    TSPINE        Thoracic Spine - Lateral Supine             136
# 17    LSPINE        W Lumbar Spine - Lateral Supine             426
#
#    KAP (uGy.m2)    kVp  Exposure (mAs) Exposure time (ms) Image Status  \
# 0          None   56.9             2.1               None     Rejected
# 1          None  124.9             4.4               None     Rejected
# 2          None   65.9             7.2               None     Rejected
# 3          None   80.9            60.8               None     Rejected
# 4          None  124.9             1.5               None     Rejected
# 5          None  124.9             1.5               None     Rejected
# 6          None  124.9             1.4               None     Rejected
# 7          None  104.9             3.3               None     Rejected
# 8          None  124.9             1.1               None     Rejected
# 9          None   89.8            40.1               None     Rejected
# 10         None   59.8             5.0               None     Rejected
# 11         None   72.9             8.1               None     Rejected
# 12         None   80.9            38.1               None     Rejected
# 13         None  124.9             3.8               None     Rejected
# 14         None   72.9             9.5               None     Rejected
# 15         None   74.8            25.1               None     Rejected
# 16         None   80.9            13.5               None     Rejected
# 17         None   89.7           192.6               None     Rejected
#
#             Reject Reason
# 0   03. Positioning Error
# 1      06. Anatomy Cutoff
# 2   03. Positioning Error
# 3      06. Anatomy Cutoff
# 4   03. Positioning Error
# 5   03. Positioning Error
# 6   03. Positioning Error
# 7      06. Anatomy Cutoff
# 8      06. Anatomy Cutoff
# 9      06. Anatomy Cutoff
# 10  03. Positioning Error
# 11  03. Positioning Error
# 12  03. Positioning Error
# 13  03. Positioning Error
# 14  03. Positioning Error
# 15  03. Positioning Error
# 16     06. Anatomy Cutoff
# 17     06. Anatomy Cutoff

# %% [markdown]
# ## Output of dataframe into .csv file

# %% [markdown]
# Check the output table above and confirm that the information matches the column names.
# If everything is OK, let's export the cleaned up .csv file into an output file.
#
# A .csv file will be created with the Asset Number and a datestamp.

# %%
# Add timestamp to filename
from datetime import datetime
date = datetime.now().strftime("%Y_%m_%d_%I_%S%p")

df_out.to_csv((r'C:\Users\BernardM\GitHub\JupyterNotebooks\rejectAnalysis\outputdata\\'
               +str(AssetNumber)
               +'_'
               +str(date)
               +'.csv')
               ,index = False, header = True)

print("The output file has been successfully created.")
# Out:
# The output file has been successfully created.

# %% [markdown]
# This output file can now be appended to the Reject Analysis and Dose Metric Dashboard database.
