# %% [markdown]
# # Philips Digital Diagnost - Image Data Table Parser

# %% [markdown]
# This notebook takes the output of the QA Tool > Image Data Table export from a Philips Digital Diagnost and produces a .csv file that can be appended to the Reject Analysis and Dose Metric Dashboard database.

# %% [markdown]
# Let's start by importing the required libraries.

# %%
import pandas as pd
import os

# %% [markdown]
# The template for the Reject Analysis and Dose Metric Dashboard is as follows:

# %%
cols_list_final = ['Asset Number','DeviceID','Manufacturer','Model','Image Date','Image Time','Body Part','View','Exposure Index','KAP (uGy.m2)','kVp','Exposure (mAs)','Exposure time (ms)','Image Status','Reject Reason']

df_template = pd.DataFrame(columns=[*cols_list_final])
df_template
# Out:
# Empty DataFrame
# Columns: [Asset Number, DeviceID, Manufacturer, Model, Image Date, Image Time, Body Part, View, Exposure Index, KAP (uGy.m2), kVp, Exposure (mAs), Exposure time (ms), Image Status, Reject Reason]
# Index: []

# %% [markdown]
# To clean up an export, you'll need to manually put in the filepath of the .csv file you want to clean up.
# <br>
# You will also be asked for your asset number so that we can group systems in the Dashboard by facility.

# %%
print("What is the filepath for the .csv file you want to clean up?")
f = input()
## Test filepath "C:/Users/BernardM/JupyterNotebooks/RejectAnalysis/inputdata/Reject_Analysis_Table_QHSCHDXC03_20201113_1.csv"

print()

print("What is the asset number of the system?")
AssetNumber = input()
# Out:
# What is the filepath for the .csv file you want to clean up?
#  C:/Users/BernardM/JupyterNotebooks/RejectAnalysis/inputdata/Reject_Analysis_Table_QHSCHDXC03_20201113_1.csv
# What is the asset number of the system?
#  123456789

# %% [markdown]
# The default filename created by the Philips QA tool includes the DeviceID on the first cell in the first column.
# <br>
# Let's extract out the DeviceID of the Philips Digital Diagnost from the Image Data Table you collected.

# %%
fn = os.path.basename(f)
DeviceID = fn[22:32]
print("The DeviceID is",DeviceID)
# Out:
# The DeviceID is QHSCHDXC03

# %% [markdown]
# Let's do some clean-up on the .csv file:
# - Skip the first four rows of the Image Data Table since they're blank
# - Define the separator. By default, this will be ";". However, this can be set to something different during export (| or , or -). Change the code below if your separator is something other than ";".

# %%
df = pd.read_csv(f, sep = ';', skiprows=4)
df
# Out:
#      Image date   Image time Study description Protocol step name step    kVp  \
# 0    02/07/2020  11:05:48 AM             Chest               Lateral L  125.0
# 1    02/07/2020  11:05:10 AM             Chest                      PA  125.0
# 2    02/07/2020  12:17:00 PM           Abdomen                      AP   77.0
# 3    03/07/2020  10:59:09 AM             Chest            AP Landscape   90.0
# 4    03/07/2020  11:31:36 AM             Chest               Lateral L  125.0
# ..          ...          ...               ...                     ...    ...
# 503  30/10/2020   1:14:36 PM             Chest               Lateral L  125.0
# 504  30/10/2020   1:13:05 PM             Chest            AP Landscape   90.0
# 505  30/10/2020   2:31:25 PM             Chest               Lateral L  125.0
# 506  30/10/2020   2:30:31 PM             Chest                      PA  125.0
# 507  30/10/2020   3:15:09 PM           Abdomen                      AP   77.0
#
#      Exposure [mAs]  Exposure time [ms] Relative x-ray exposure  \
# 0              27.0                53.0                     641
# 1               2.0                 4.0                     306
# 2               8.0                 9.0                     196
# 3               2.0                10.0                     372
# 4              10.0                20.0                     358
# ..              ...                 ...                     ...
# 503            26.0                49.0                     444
# 504             2.0                10.0                     338
# 505             6.0                11.0                     487
# 506             2.0                 3.0                     382
# 507             7.0                 8.0                     206
#
#     Image dose area product [µGy m²] Image comments Reject reason     Status  \
# 0                             104.41            NaN           NaN  confirmed
# 1                               7.48            NaN           NaN  confirmed
# 2                              48.55            NaN           NaN  confirmed
# 3                                 18            NaN           NaN  confirmed
# 4                              38.94            NaN           NaN  confirmed
# ..                               ...            ...           ...        ...
# 503                            113.7            NaN           NaN  confirmed
# 504                             9.69            NaN           NaN  confirmed
# 505                            22.95            NaN           NaN  confirmed
# 506                             6.57            NaN           NaN  confirmed
# 507                            49.34            NaN           NaN  confirmed
#
#     Modality Operators name Image link Patient sex Patient's age  \
# 0         DX           user    [Image]           M          069Y
# 1         DX           user    [Image]           M          069Y
# 2         DX           user    [Image]           F          084Y
# 3         DX           user    [Image]           M          066Y
# 4         DX             BR    [Image]           F          066Y
# ..       ...            ...        ...         ...           ...
# 503       DX           user    [Image]           M          069Y
# 504       DX           user    [Image]           M          069Y
# 505       DX           user    [Image]           M          082Y
# 506       DX           user    [Image]           M          082Y
# 507       DX           user    [Image]           F          016Y
#
#     Pregnancy status  Unnamed: 18
# 0            Unknown          NaN
# 1            Unknown          NaN
# 2            Unknown          NaN
# 3            Unknown          NaN
# 4            Unknown          NaN
# ..               ...          ...
# 503          Unknown          NaN
# 504          Unknown          NaN
# 505          Unknown          NaN
# 506          Unknown          NaN
# 507          Unknown          NaN
#
# [508 rows x 19 columns]

# %% [markdown]
# If the .csv file has been read in correctly above, you should see a table with all the values from the log.
# <br>
# Let's add a few identifiers for filtering purposes:
# - Asset Number
# - Device ID (e.g. unique system ID, serial number or even room number)
# - Manufacturer
# - Model

# %%
cols_list = ['Asset Number','DeviceID','Manufacturer','Model']
df = df.reindex(columns=[*cols_list,*df.columns.tolist()])

df['Asset Number'] = AssetNumber
df['DeviceID'] = DeviceID
df['Manufacturer'] = "Philips"
df['Model'] = "Digital Diagnost"
df
# Out:
#     Asset Number    DeviceID Manufacturer             Model  Image date  \
# 0      123456789  QHSCHDXC03      Philips  Digital Diagnost  02/07/2020
# 1      123456789  QHSCHDXC03      Philips  Digital Diagnost  02/07/2020
# 2      123456789  QHSCHDXC03      Philips  Digital Diagnost  02/07/2020
# 3      123456789  QHSCHDXC03      Philips  Digital Diagnost  03/07/2020
# 4      123456789  QHSCHDXC03      Philips  Digital Diagnost  03/07/2020
# ..           ...         ...          ...               ...         ...
# 503    123456789  QHSCHDXC03      Philips  Digital Diagnost  30/10/2020
# 504    123456789  QHSCHDXC03      Philips  Digital Diagnost  30/10/2020
# 505    123456789  QHSCHDXC03      Philips  Digital Diagnost  30/10/2020
# 506    123456789  QHSCHDXC03      Philips  Digital Diagnost  30/10/2020
# 507    123456789  QHSCHDXC03      Philips  Digital Diagnost  30/10/2020
#
#       Image time Study description Protocol step name step    kVp  \
# 0    11:05:48 AM             Chest               Lateral L  125.0
# 1    11:05:10 AM             Chest                      PA  125.0
# 2    12:17:00 PM           Abdomen                      AP   77.0
# 3    10:59:09 AM             Chest            AP Landscape   90.0
# 4    11:31:36 AM             Chest               Lateral L  125.0
# ..           ...               ...                     ...    ...
# 503   1:14:36 PM             Chest               Lateral L  125.0
# 504   1:13:05 PM             Chest            AP Landscape   90.0
# 505   2:31:25 PM             Chest               Lateral L  125.0
# 506   2:30:31 PM             Chest                      PA  125.0
# 507   3:15:09 PM           Abdomen                      AP   77.0
#
#      Exposure [mAs]  ...  Image comments Reject reason     Status Modality  \
# 0              27.0  ...             NaN           NaN  confirmed       DX
# 1               2.0  ...             NaN           NaN  confirmed       DX
# 2               8.0  ...             NaN           NaN  confirmed       DX
# 3               2.0  ...             NaN           NaN  confirmed       DX
# 4              10.0  ...             NaN           NaN  confirmed       DX
# ..              ...  ...             ...           ...        ...      ...
# 503            26.0  ...             NaN           NaN  confirmed       DX
# 504             2.0  ...             NaN           NaN  confirmed       DX
# 505             6.0  ...             NaN           NaN  confirmed       DX
# 506             2.0  ...             NaN           NaN  confirmed       DX
# 507             7.0  ...             NaN           NaN  confirmed       DX
#
#     Operators name Image link Patient sex Patient's age Pregnancy status  \
# 0             user    [Image]           M          069Y          Unknown
# 1             user    [Image]           M          069Y          Unknown
# 2             user    [Image]           F          084Y          Unknown
# 3             user    [Image]           M          066Y          Unknown
# 4               BR    [Image]           F          066Y          Unknown
# ..             ...        ...         ...           ...              ...
# 503           user    [Image]           M          069Y          Unknown
# 504           user    [Image]           M          069Y          Unknown
# 505           user    [Image]           M          082Y          Unknown
# 506           user    [Image]           M          082Y          Unknown
# 507           user    [Image]           F          016Y          Unknown
#
#     Unnamed: 18
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 503         NaN
# 504         NaN
# 505         NaN
# 506         NaN
# 507         NaN
#
# [508 rows x 23 columns]

# %% [markdown]
# Let's match the .csv columns into the template:
# - rename the columns of the original .csv file to match the template
# - remove any columns we don't need
# - rearrange the columns to match the template

# %%
df = df.rename(columns={"Study description": "Body Part",
                       "Protocol step name step": "View",
                        "Relative x-ray exposure": "Exposure Index",
                        "Exposure [mAs]": "Exposure (mAs)",
                        "Exposure time [ms]": "Exposure time (ms)",
                        "Status": "Image Status",
                        "Reject reason": "Reject Reason",
                        "Image dose area product [µGy m²]": "KAP (uGy.m2)",
                        "Image date": "Image Date",
                        "Image time": 'Image Time'
                       })

df_out = df[[*cols_list_final]]

df_out
# Out:
#     Asset Number    DeviceID Manufacturer             Model  Image Date  \
# 0      123456789  QHSCHDXC03      Philips  Digital Diagnost  02/07/2020
# 1      123456789  QHSCHDXC03      Philips  Digital Diagnost  02/07/2020
# 2      123456789  QHSCHDXC03      Philips  Digital Diagnost  02/07/2020
# 3      123456789  QHSCHDXC03      Philips  Digital Diagnost  03/07/2020
# 4      123456789  QHSCHDXC03      Philips  Digital Diagnost  03/07/2020
# ..           ...         ...          ...               ...         ...
# 503    123456789  QHSCHDXC03      Philips  Digital Diagnost  30/10/2020
# 504    123456789  QHSCHDXC03      Philips  Digital Diagnost  30/10/2020
# 505    123456789  QHSCHDXC03      Philips  Digital Diagnost  30/10/2020
# 506    123456789  QHSCHDXC03      Philips  Digital Diagnost  30/10/2020
# 507    123456789  QHSCHDXC03      Philips  Digital Diagnost  30/10/2020
#
#       Image Time Body Part          View Exposure Index KAP (uGy.m2)    kVp  \
# 0    11:05:48 AM     Chest     Lateral L            641       104.41  125.0
# 1    11:05:10 AM     Chest            PA            306         7.48  125.0
# 2    12:17:00 PM   Abdomen            AP            196        48.55   77.0
# 3    10:59:09 AM     Chest  AP Landscape            372           18   90.0
# 4    11:31:36 AM     Chest     Lateral L            358        38.94  125.0
# ..           ...       ...           ...            ...          ...    ...
# 503   1:14:36 PM     Chest     Lateral L            444        113.7  125.0
# 504   1:13:05 PM     Chest  AP Landscape            338         9.69   90.0
# 505   2:31:25 PM     Chest     Lateral L            487        22.95  125.0
# 506   2:30:31 PM     Chest            PA            382         6.57  125.0
# 507   3:15:09 PM   Abdomen            AP            206        49.34   77.0
#
#      Exposure (mAs)  Exposure time (ms) Image Status Reject Reason
# 0              27.0                53.0    confirmed           NaN
# 1               2.0                 4.0    confirmed           NaN
# 2               8.0                 9.0    confirmed           NaN
# 3               2.0                10.0    confirmed           NaN
# 4              10.0                20.0    confirmed           NaN
# ..              ...                 ...          ...           ...
# 503            26.0                49.0    confirmed           NaN
# 504             2.0                10.0    confirmed           NaN
# 505             6.0                11.0    confirmed           NaN
# 506             2.0                 3.0    confirmed           NaN
# 507             7.0                 8.0    confirmed           NaN
#
# [508 rows x 15 columns]

# %% [markdown]
# Finally, let's export the cleaned up .csv file into an output file. Finally, let's export the cleaned up .csv file into an output file. By default, this creates a new .csv file with the name "df_out". Change the code below to rename it to something unique with a timestamp if preferred.

# %%
df_out.to_csv(r'C:\Users\BernardM\JupyterNotebooks\RejectAnalysis\outputdata\df_out.csv',index = False, header = True)

# %% [markdown]
# This output file can now be appended to the Reject Analysis and Dose Metric Dashboard database.
